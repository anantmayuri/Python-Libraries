# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.arr([1,6])
ypoints = np.arr([0,250])
plt.plot(xpoints , ypoints)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 3
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 3 xpoints = np.arr([1,6])
#       4 ypoints = np.arr([0,250])
#       5 plt.plot(xpoints , ypoints)
#
# File ~\anaconda3\Lib\site-packages\numpy\__init__.py:333, in __getattr__(attr)
#     330     "Removed in NumPy 1.25.0"
#     331     raise RuntimeError("Tester was removed in NumPy 1.25.")
# --> 333 raise AttributeError("module {!r} has no attribute "
#     334                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'arr'

# %%
import matplotlib.pyplot as plt

# %%
x= [1,2,3]
y= [2,4,1]

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.show()

# %%
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.plot(x,y)
plt.title("Mayu")
plt.show()

# %%
plt.close()

# %%
#line 1 points
x1=[1,2,3]
y1=[2,4,1]
#line 2 points
x2=[1,2,3]
y2=[4,1,3]

# %%
plt.plot(x1,y1,label='line1')
plt.plot(x2,y2,label='line2')
plt.legend()
plt.show()
